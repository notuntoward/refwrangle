# %% [markdown]
# ### Test of some jupyter magics
# From: https://medium.com/top-python-libraries/10-jupyter-notebook-features-you-didnt-know-they-exist-349e01cf5f58
#
# **Possibly useful**
# - ipywidgets.interactive
# - docs (marginally)
# - source (marginally)
#
# Would be nice if the debugger worked.  Maybe it does, but I couldn't figure it out in a few minutes.

# %%
# didn't work
# %%bash  
# df -h

# %%
# interatie slider
import numpy as np
from ipywidgets import interact

def f(x):
    return np.arange(0.1, 1.0, 0.1)**x
interact(f, x=10)
# Out:
# interactive(children=(IntSlider(value=10, description='x', max=30, min=-10), Output()), _dom_classes=('widget-…
# <function __main__.f(x)>

# %%
# doc in cell
import pandas as pd
pd.DataFrame?

# %%
# source code

np.linalg.inv??

# %%
# realtime debugging.  In vscode, makes a popup that never goes away.  Not sure how to use it.
# %pdb on

# def f(x):
#     return 1/x

# f(0)
