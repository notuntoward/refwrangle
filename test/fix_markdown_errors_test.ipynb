# %% [markdown]
# ### Fix markdown errors
#
# Started from [here](https://www.perplexity.ai/search/find-a-markdown-linter-that-re-tCZ5exLNS6eg_erkgJflhQ#10)

# %%
import pathlib as pl
from icecream import ic
import sys
import os

#normalized_path = os.path.normpath(path)

refwrangle_dir = pl.Path('~/ref/refwrangle').expanduser() # can't reliably get dir of an .ipynb 
sys.path.append(str(refwrangle_dir))
import refwrangle as rfw

# %%
# Sample Markdown content with errors
sample_markdown = """# Header 1

## Header 2

**Bold text

#### Header 4

Some `inline code

## asdflkj asdflkj asflk asdflkjas df asdfl;kadsjf asdf asdf asdfasdflkasdfl  asdflkjasdf asdf asdlfkj asdlk  asdfalk asdas flasdf asdf asdfl;kjadsfj

## f

*Italic text"""

# Call the function to fix the markdown errors
repaired_markdown = rfw.fix_markdown_errors(sample_markdown)

# Output the repaired markdown
print("Repaired Markdown:")
print(repaired_markdown)
# Out:
# Repaired Markdown:
# # Header 1
#
# ## Header 2
#
# **Bold text**
#
# ### Header 4
#
# Some `inline code`
#
# asdflkj asdflkj asflk asdflkjas df asdfl;kadsjf asdf asdf asdfasdflkasdfl  asdflkjasdf asdf asdlfkj asdlk  asdfalk asdas flasdf asdf asdfl;kjadsfj
#
# f
#
# *Italic text*
