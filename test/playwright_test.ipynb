# %% [markdown]
# #### Test for running inside Jupyter
#
# Doesn't work.  Was a [known bug in 2023](https://stackoverflow.com/a/75223003/2591097), and it's still there

# %%
from playwright.sync_api import sync_playwright
import pathlib
import os

# convert a relative path of a local file into absolute path
# you can skip this if you have an absolute path like "C:\\Users\\James\\reports\\sales_report.html"
filePath = os.path.abspath(r"C:\Users\scott\OneDrive\share\ref\refwrangle\test\Dionne24hiddenVictoryProgrssiv.html")

# derive the URL path of a local file to be opened in browser
fileUrl = pathlib.Path(filePath).as_uri()

# print the file as a pdf from chromium browser using playwright
with sync_playwright() as p:
    # create a browser instance
    browser = p.chromium.launch()

    # open a new tab in the browser
    page = browser.new_page()

    # goto the URL of the HTML page
    page.goto(fileUrl)

    # change css media type to screen
    page.emulate_media(media="screen")

    # print the html page as pdf in the browser
    page.pdf(path="./tmp.pdf", format="A4",
             landscape=True, margin={"top": "2cm"})
    
    # close the browser
    browser.close()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[10], line 13
#      10 fileUrl = pathlib.Path(filePath).as_uri()
#      12 # print the file as a pdf from chromium browser using playwright
# ---> 13 with sync_playwright() as p:
#      14     # create a browser instance
#      15     browser = p.chromium.launch()
#      17     # open a new tab in the browser
#
# File c:\Users\scott\miniconda3\Lib\site-packages\playwright\sync_api\_context_manager.py:47, in PlaywrightContextManager.__enter__(self)
#      45             self._own_loop = True
#      46         if self._loop.is_running():
# ---> 47             raise Error(
#      48                 """It looks like you are using Playwright Sync API inside the asyncio loop.
#      49 Please use the Async API instead."""
#      50             )
# ...

# %% [markdown]
# project="HTMLtoPDF"
# file="playwright_pdf_generator.py"
# version=2
# import asyncio
# from playwright.async_api import async_playwright
#
# async def generate_pdf_with_playwright(url, pdf_path):
#     async with async_playwright() as p:
#         browser = await p.chromium.launch()
#         page = await browser.new_page()
#         await page.goto(url)
#         # Optionally, add waits or interactions here if needed
#         await page.pdf(path=pdf_path)
#         await browser.close()
#
# # Example usage:  Replace with your URL and desired PDF path
# url = "https://www.example.com"
# pdf_path = "example.pdf"
#
# asyncio.run(generate_pdf_with_playwright(url, pdf_path))

# %% [markdown]
# #### Test for when running outside of Jupyter, I think.
# Inside Jupyter, I get the error:
#
# Error: It looks like you are using Playwright Sync API inside the asyncio loop.
# Please use the Async API instead.

# %%
with sync_playwright() as p:
    browser = p.chromium.launch()
    page = browser.new_page()
    page.goto("https://example.com")
    print(page.title())
    browser.close()
