# %% [markdown]
# ### Directly download and attach html files to zotero item
# From: [here](https://www.perplexity.ai/search/is-there-a-way-to-programmatic-1YF38BNdQ8inPoSsAK8WDw#5)
#
# **Doesn't work**

# %%
from icecream import ic
import pathlib as pl
from pyzotero import zotero
import pandas as pd
from IPython.display import display, HTML
import pathlib as pl
from icecream import ic
import sys

refwrangle_dir = pl.Path('~/ref/refwrangle').expanduser() # can't reliably get dir of an .ipynb 
sys.path.append(str(refwrangle_dir))
import refwrangle as rfw
import re

# %load_ext autoreload
# %autoreload 2

# %%
from pyzotero import zotero
import requests

# # Initialize Zotero client
# library_id = 'your_library_id'
# api_key = 'your_api_key'
# zot = zotero.Zotero(library_id, 'user', api_key)

parent_key = 'SUISKUY6' # Wodecki24yannLeCunDitchGenAI
webpage_url = 'https://www.washingtonpost.com/opinions/2025/01/23/great-stay-mortgage-rates-hiring/' # random page
attachment_title = 'Example Web Page Snapshot'

zot = zotero.Zotero(rfw.library_id, rfw.library_type, rfw.api_key)

def attach_webpage(parent_key, url, title):
    # Download the web page
    response = requests.get(url)
    content = response.text

    # Prepare attachment data
    attachment_template = zot.item_template('attachment', 'imported_url')
    attachment_template['title'] = title
    attachment_template['url'] = url
    attachment_template['parentItem'] = parent_key

    # Create attachment
    attachment = zot.create_items([attachment_template])
    
    # Upload the content
    zot.upload_attachment(content, attachment[0]['key'])

    print(f"Web page attached successfully: {attachment}")

# Example usage
attach_webpage(parent_key, webpage_url, attachment_title)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\scott\miniconda3\envs\refwrangle\Lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\scott\miniconda3\envs\refwrangle\Lib\site-packages\urllib3\connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461 try:
# ...
