# %% [markdown]
# ### Tests conversion of markdown to a pdf file using the markdown and reportlab libraries
#
# Started from [here](https://www.perplexity.ai/search/modify-one-or-both-of-the-html-RV25YyK_QHqGSjNh7bKwvg#2)

# %%
import pathlib as pl
from icecream import ic
import sys

refwrangle_dir = pl.Path('~/ref/refwrangle').expanduser() # can't reliably get dir of an .ipynb 
sys.path.append(str(refwrangle_dir))
import refwrangle as rfw

# %%
bFNm = 'Ansolabehere24forecastTurnout.md'
input_file = rfw.attachments_as_md_cachedir / bFNm
output_file = pl.Path("tmp_md2pdf_markdown_reportlab].pdf")

# %%
ic(input_file, output_file)

with input_file.open('r', encoding='utf-8') as source_file:
    markdown_content = source_file.read()    

rfw.md2pdf_markdown_reportlab(markdown_content, output_file)
# Out:
# ic| input_file: WindowsPath('C:/Users/scott/OneDrive/share/ref/refwrangle/dat/proc/attachments_as_md_cache/Ansolabehere24forecastTurnout.md')
#     output_file: WindowsPath('tmp_md2pdf_markdown_reportlab].pdf')
