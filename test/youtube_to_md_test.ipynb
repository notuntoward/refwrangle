# %% [markdown]
# #### Tests download of a youtube video transcript, writing to pdf

# %%
# %load_ext autoreload
# %autoreload 2

import pathlib as pl
refwrangle_dir = pl.Path('~/ref/refwrangle').expanduser() # can't reliably get dir of an .ipynb 
import sys
sys.path.append(str(refwrangle_dir))
import refwrangle as rfw
from icecream import ic
tmpdir = rfw.refwrangle_dir / 'test' / 'tmp'

video_url = "https://www.youtube.com/watch?v=TaG2zCVotxE"
video_url = "https://www.youtube.com/watch?v=SfbfaA8kriI&lc=UgzN8sBNchKp6Vp3Y3Z4AaABAg.ADK37ub-LsWADdVyBJk1Lw"
output_file = tmpdir / "tmp_yt_transcript.md"
ic(video_url, output_file)

rfw.youtube2md(video_url, output_file);
# Out:
# ic| video_url: 'https://www.youtube.com/watch?v=SfbfaA8kriI&lc=UgzN8sBNchKp6Vp3Y3Z4AaABAg.ADK37ub-LsWADdVyBJk1Lw'
#     output_file: WindowsPath('C:/Users/scott/OneDrive/share/ref/refwrangle/test/tmp/tmp_yt_transcript.md')
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
