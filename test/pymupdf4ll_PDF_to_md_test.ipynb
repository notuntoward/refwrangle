# %% [markdown]
# ### Test of pdf --> markdown using pymupdf4llm
#
# See [The PDF Extraction Revolution: Why PymuPDF4llm is Your New Best Friend (and LlamaParse is Crying)](https://ai.gopubby.com/the-pdf-extraction-revolution-why-pymupdf4llm-is-your-new-best-friend-and-llamaparse-is-crying-e57882dee7f8)

# %%
import pathlib as pl
import sys
refwrangle_dir = pl.Path('~/ref/refwrangle').expanduser() # can't reliably get dir of your .ipynb 
sys.path.append(str(refwrangle_dir))
import refwrangle as rfw
test_dir = refwrangle_dir / 'test'

from icecream import ic

#pdf_basename = 'Cousens24voterEngageHistoryPost.pdf' 
#pdf_basename = 'Towler23rapidQualTextMLcovid.pdf'
pdf_basename = 'Dimitrov24detPersuadeTechMemes.pdf'
# pdf_basename = 'FAIR24fairVsWalkerLoanDiscrim.pdf'
# pdf_basename = 'Emanuele15datasetElectVolWestEUdownload.pdf'
# pdf_basename = 'Anonymous24RealMedianEarnings.pdf'
pdf_basename = pdf_basename = 'Tomeo21predElectAgeSocMedia.pdf' # misses a lot of headlines
pdf_basename = 'Healy25masculinPodTrump.pdf'  # too many very long headlines
pdf_file = rfw.lit_attachment_dir_shared / pdf_basename

md_file = test_dir / 'tmp_pymupdf4llm_pdf_to_md.md'

ic(pdf_file, md_file)

rfw.pdf2md_pymupdf4llm(pdf_file, md_file)

print('Done.')
# Out:
# ic| pdf_file: WindowsPath('C:/Users/scott/OneDrive/share/ref/obsidian/Obsidian Share Vault/lit/lit_sources/Healy25masculinPodTrump.pdf')
#     md_file: WindowsPath('C:/Users/scott/ref/refwrangle/test/tmp_pymupdf4llm_pdf_to_md.md')
# Done.
